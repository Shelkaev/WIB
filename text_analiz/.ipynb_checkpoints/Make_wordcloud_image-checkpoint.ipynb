# %%
import re
import numpy as np
import pickle

import pymorphy2

from wordcloud import WordCloud

# Gensim
import gensim


import nltk
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('stopwords')
lemma = WordNetLemmatizer()


import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
import pymorphy2
# Out:
# [nltk_data] Downloading package wordnet to /home/artem/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/artem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
prepare = True

# %%
#Приведение слов в нормальную форму при помощи pymorphy2

# %%
morph = pymorphy2.MorphAnalyzer(lang='uk')
f = open('News.txt')
p = morph.parse(f.read())[0]
data_normal_words = p.normal_form

with open('News_normalized.txt', 'w') as file:
       file.write(data_normal_words)

f.close()

# %%
print(data_normal_words)
# Out:
# 'u.s. presidents george w. bush and barack obama, when first elected, both thought they could establish a rapport with russian leader vladimir putin and dramatically improve u.s.-russian relations.', 'their appraisal of putin swiftly changed.', 'when asked his impression of putin after his first face-to-face meeting, george w. bush said, “i looked the man in the eye. i found him very straightforward and trustworthy – i was able to get a sense of his soul.” obama, eight years later, openly sought a reset in relations only to see his hopes dashed finally with russia’s annexation of the ukrainian peninsula crimea in 2014.', 'joe biden, who as obama’s vice president supported the reset strategy, is unlikely to follow the example of his predecessors, say former diplomats and analysts. biden indicated as much during his presidential campaign, saying at a cnn town hall last month, “i believe russia is an opponent, i really do.”', 'in contrast, he called china “a competitor, a serious competitor.”', 'during the presidential campaign, biden sought to differentiate himself from president donald trump regarding russia, accusing his republican rival of being soft on putin.', 'trump and his aides pushed back, with the president saying in august, “the last person russia wants to see in office is donald trump because nobody’s been tougher on russia than i have.”', 'early last month, biden criticized his opponent for remaining silent on the poisoning of russian opposition leader alexei navalny, which he bluntly blamed on the moscow government.', '“once again, the kremlin has used a favorite weapon — an agent from the novichok class of chemicals — in an effort to silence a political opponent,” he said. “it is the mark of a russian regime that is so paranoid that it is unwilling to tolerate any criticism or dissent.”', 'but candidates can say one thing during a campaign and do something else once in office; sometimes they have little choice because of circumstances or the course of events. will a president joe biden pursue as muscular an approach to russia as he has suggested?', "“i don't think biden is going to fall head over heels to butter up putin,” said david kramer, who was an assistant secretary of state in the administration of george w. bush. “moscow has continued with a disinformation campaign against him, and so i don't think he's going to extend a hand and say, ‘let's make nice,’” added kramer, now a fellow at the mccain institute, a foreign policy think tank based in washington.", '“i mean, no reset. i don’t think he’s going to try anything like 2009,” kramer said in reference to obama’s failed reset policy. kramer thinks biden will have to focus largely on domestic issues, thanks to the coronavirus pandemic and its economic impact.', "“and to the extent he is able to focus on foreign policy, russia should not be at the high end of the priority list,” he told voa. although he added, “you can't ignore it. and it is a factor in a number of problems we face. i think he's going to have to devote his limited time when it comes to foreign policy to work with countries that are ready to solve problems.” by that he means shoring up america’s transatlantic alliance.", 'biden and putin have met — without much cordiality. in a 2011 interview with ', ' magazine, biden said at one meeting he told the russian leader, “i’m looking into your eyes, and i don’t think you have a soul.”', 'biden continued: “he looked back at me, and he smiled, and he said: ‘we understand one another.’”', 'aside from the lack of personal rapport, analysts say any effort to reset relations would be complicated by economic sanctions on russia, imposed by both the obama and trump administrations. the measures will leave biden with little room to maneuver and are unlikely to be lifted while western powers believe russia is mounting cyberattacks against them.', 'former western diplomats say antagonism is likely to persist between washington and moscow as long as the kremlin ...

# %%
#Создаем словарь мусорных слов

# %%
stop_words = stopwords.words('english')
stop_words = ['xa', '.', 'one', 'first', 'many', 'well', 'will', 
              'need','russian', 'russia', 'now', 'know', 'ha', 'wa', 
              'said','new', 'time', 'make', 'including', 'two', 
              'even', 'think', 'say', 'take', 'part', 'day',
              'long', 'much', 'may', 'back', 'says', 'year',
              'around', 'news', 'without', 'data']
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
stop_words = set(stop_words)

# %%
def clean(text):
    # Remove new line characters
    text = re.sub('\s+', ' ', text)
    # Remove distracting single quotes
    text = re.sub("\'", "", text)
    return text


def doc_to_words(doc, stop_words, lemma):
    stop_words = set(stop_words)
    # remove stop words and punctuation
    words = [w for w in gensim.utils.simple_preprocess(str(doc), deacc=True) if w not in stop_words]
    return words

# %%
# Очищаем данные по словарю

# %%
if prepare:
    file = open('News_normalized.txt') #News.txt
    # Convert to list
    data = file
    data = [clean(t) for t in data]
    data_clean_words = [doc_to_words(t, stop_words, lemma) for t in data]
    file.close()
    with open('Bag_words_news.pkl', 'wb') as f:
        pickle.dump(data_clean_words, f)
else:
    with open('Bag_words_news.pkl', 'rb') as f:
        data_clean_words= pickle.load(f)

# %%
print(data_clean_words[0][:10])
# Out:
# ['presidents', 'george', 'bush', 'and', 'barack', 'obama', 'when', 'elected', 'both', 'thought']

# %%
#Добавляем биграмы

# %%
if prepare:
    # Build the bigram and trigram models
    bigram = gensim.models.Phrases(data_clean_words, min_count=5, threshold=100) # higher threshold fewer phrases.
    
    # Faster way to get a sentence clubbed as a trigram/bigram
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    bigram_mod.save('bigram_mod.pkl')
    data_words_bigrams = [bigram_mod[w] for w in data_clean_words]
    with open('bigrams.pkl', 'wb') as f:
        pickle.dump(data_words_bigrams, f)

else:
    bigram_mod = gensim.models.Phrases.load('bigram_mod.pkl')
    
    with open('bigrams.pkl', 'rb') as f:
        data_words_bigrams = pickle.load(f)

# %%
print(data_words_bigrams[:100])
# Out:
# [['presidents', 'george', 'bush', 'and', 'barack_obama', 'when', 'elected', 'both', 'thought', 'they', 'could', 'establish', 'rapport', 'with', 'leader', 'vladimir_putin', 'and', 'dramatically', 'improve', 'relations', 'their', 'appraisal', 'of', 'putin', 'swiftly', 'changed', 'when', 'asked', 'his', 'impression', 'of', 'putin', 'after', 'his', 'face', 'to', 'face', 'meeting', 'george', 'bush', 'looked', 'the', 'man', 'in', 'the', 'eye', 'found', 'him', 'very', 'straightforward', 'and', 'trustworthy', 'was', 'able', 'to', 'get', 'sense', 'of', 'his', 'soul', 'obama', 'eight', 'years', 'later', 'openly', 'sought', 'reset', 'in', 'relations', 'only', 'to', 'see', 'his', 'hopes', 'dashed', 'finally', 'with', 'annexation', 'of', 'the', 'ukrainian', 'peninsula', 'crimea', 'in', 'joe_biden', 'who', 'as', 'obama', 'vice_president', 'supported', 'the', 'reset', 'strategy', 'is', 'unlikely', 'to', 'follow', 'the', 'example', 'of', 'his', 'predecessors', 'former', 'diplomats', 'and', 'analysts', 'biden', 'indicated', 'as', 'during', 'his', 'presidential', 'campaign', 'saying', 'at', 'cnn', 'town', 'hall', 'last_month', 'believe', 'is', 'an', 'opponent', 'really', 'do', 'in', 'contrast', 'he', 'called', 'china', 'competitor', 'serious', 'competitor', 'during', 'the', 'presidential', 'campaign', 'biden', 'sought', 'to', 'differentiate', 'himself', 'president', 'donald_trump', 'regarding', 'accusing', 'his', 'republican', 'rival', 'of', 'being', 'soft', 'on', 'putin', 'trump', 'and', 'his', 'aides', 'pushed', 'with', 'the', 'president', 'saying', 'in', 'august', 'the', 'last', 'person', 'wants', 'to', 'see', 'in', 'office', 'is', 'donald_trump', 'because', 'nobody', 'been', 'tougher', 'on', 'than', 'have', 'early', 'last_month', 'biden', 'criticized', 'his', 'opponent', 'for', 'remaining', 'silent', 'on', 'the', 'poisoning', 'of', 'opposition_leader', 'alexei', 'navalny', 'which', 'he', 'bluntly', 'blamed', 'on', 'the', 'moscow', 'government', 'once', 'again', 'the', 'kremlin', 'has', 'used', 'favorite', 'weapon', 'an', 'agent', 'the', 'novichok', 'class', 'of', 'chemicals', 'in', 'an', 'effort', 'to', 'silence', 'political', 'opponent', 'he', 'it', 'is', 'the', 'mark', 'of', 'regime', 'that', 'is', 'so', 'paranoid', 'that', 'it', 'is', 'unwilling', 'to', 'tolerate', 'any', 'criticism', 'or', 'dissent', 'but', 'candidates', 'can', 'thing', 'during', 'campaign', 'and', 'do', 'something', 'else', 'once', 'in', 'office', 'sometimes', 'they', 'have', 'little', 'choice', 'because', 'of', 'circumstances', 'or', 'the', 'course', 'of', 'events', 'president', 'joe_biden', 'pursue', 'as', 'muscular', 'an', 'approach', 'to', 'as', 'he', 'has', 'suggested', 'dont', 'biden', 'is', 'going', 'to', 'fall', 'head', 'over', 'heels', 'to', 'butter', 'up', 'putin', 'david', 'kramer', 'who', 'was', 'an', 'assistant', 'secretary', 'of', 'state', 'in', 'the', 'administration', 'of', 'george', 'bush', 'moscow', 'has', 'continued', 'with', 'disinformation', 'campaign', 'against', 'him', 'and', 'so', 'dont', 'hes', 'going', 'to', 'extend', 'hand', 'and', 'lets', 'nice', 'added', 'kramer', 'fellow', 'at', 'the', 'mccain', 'institute', 'foreign_policy', 'tank', 'based', 'in', 'washington', 'mean', 'no', 'reset', 'don', 'he', 'going', 'to', 'try', 'anything', 'like', 'kramer', 'in', 'reference', 'to', 'obama', 'failed', 'reset', 'policy', 'kramer', 'thinks', 'biden', 'have', 'to', 'focus', 'largely', 'on', 'domestic', 'issues', 'thanks', 'to', 'the', 'coronavirus', 'pandemic', 'and', 'its', 'economic', 'impact', 'and', 'to', 'the', 'extent', 'he', 'is', 'able', 'to', 'focus', 'on', 'foreign_policy', 'should', 'not', 'be', 'at', 'the', 'high', 'end', 'of', 'the', 'priority', 'list', 'he', 'told', 'voa', 'although', 'he', 'added', 'you', 'cant', 'ignore', 'it', 'and', 'it', 'is', 'factor', 'in', 'number', 'of', 'problems', 'we', 'face', 'hes', 'going', 'to', 'have', 'to', 'devote', 'his', 'limited', 'when', 'it', 'comes', 'to', 'foreign_policy', 'to', 'work', 'with', 'c ...

# %%
#Склейка текста

# %%
unit_text = ''
for i in range(len(data_words_bigrams[0])):
    unit_text += data_words_bigrams[0][i] + ' '
    
print(unit_text)
# Out:
# presidents george bush and barack_obama when elected both thought they could establish rapport with leader vladimir_putin and dramatically improve relations their appraisal of putin swiftly changed when asked his impression of putin after his face to face meeting george bush looked the man in the eye found him very straightforward and trustworthy was able to get sense of his soul obama eight years later openly sought reset in relations only to see his hopes dashed finally with annexation of the ukrainian peninsula crimea in joe_biden who as obama vice_president supported the reset strategy is unlikely to follow the example of his predecessors former diplomats and analysts biden indicated as during his presidential campaign saying at cnn town hall last_month believe is an opponent really do in contrast he called china competitor serious competitor during the presidential campaign biden sought to differentiate himself president donald_trump regarding accusing his republican rival of being soft on putin trump and his aides pushed with the president saying in august the last person wants to see in office is donald_trump because nobody been tougher on than have early last_month biden criticized his opponent for remaining silent on the poisoning of opposition_leader alexei navalny which he bluntly blamed on the moscow government once again the kremlin has used favorite weapon an agent the novichok class of chemicals in an effort to silence political opponent he it is the mark of regime that is so paranoid that it is unwilling to tolerate any criticism or dissent but candidates can thing during campaign and do something else once in office sometimes they have little choice because of circumstances or the course of events president joe_biden pursue as muscular an approach to as he has suggested dont biden is going to fall head over heels to butter up putin david kramer who was an assistant secretary of state in the administration of george bush moscow has continued with disinformation campaign against him and so dont hes going to extend hand and lets nice added kramer fellow at the mccain institute foreign_policy tank based in washington mean no reset don he going to try anything like kramer in reference to obama failed reset policy kramer thinks biden have to focus largely on domestic issues thanks to the coronavirus pandemic and its economic impact and to the extent he is able to focus on foreign_policy should not be at the high end of the priority list he told voa although he added you cant ignore it and it is factor in number of problems we face hes going to have to devote his limited when it comes to foreign_policy to work with countries that are ready to solve problems by that he means shoring up america transatlantic alliance biden and putin have met cordiality in interview with magazine biden at meeting he told the leader looking into your eyes and don you have soul biden continued he looked at me and he smiled and he we understand another aside the lack of personal rapport analysts any effort to reset relations would be complicated by economic sanctions on imposed by both the obama and trump administrations the measures leave biden with little room to maneuver and are unlikely to be lifted while western powers believe is mounting cyberattacks against them former western diplomats antagonism is likely to persist between washington and moscow as as the kremlin seeks to undermine western democratic institutions last_week former top security_adviser to british prime_minister boris johnson mark sedwill revealed that britain has launched series of covert cyber based attacks on leaders and their interests to impose price greater than they might have expected for their cyber offensive against the west other allied powers the are doing so too western intelligence officials in what is becoming like for like cyber conflict with the kremlin in the so called gray space the gap between normal state relations and armed conflict the and othe ...

# %%
#Очистка от предлогов

# %%
pat = r'\b[a-zA-Z_]{3,}\b'
re_text = re.findall(pat, unit_text)
re_unit_text = ''
for i in range(len(re_text)):
    re_unit_text += re_text[i] + ' '
    
print(re_unit_text)
# Out:
# presidents george bush and barack_obama when elected both thought they could establish rapport with leader vladimir_putin and dramatically improve relations their appraisal putin swiftly changed when asked his impression putin after his face face meeting george bush looked the man the eye found him very straightforward and trustworthy was able get sense his soul obama eight years later openly sought reset relations only see his hopes dashed finally with annexation the ukrainian peninsula crimea joe_biden who obama vice_president supported the reset strategy unlikely follow the example his predecessors former diplomats and analysts biden indicated during his presidential campaign saying cnn town hall last_month believe opponent really contrast called china competitor serious competitor during the presidential campaign biden sought differentiate himself president donald_trump regarding accusing his republican rival being soft putin trump and his aides pushed with the president saying august the last person wants see office donald_trump because nobody been tougher than have early last_month biden criticized his opponent for remaining silent the poisoning opposition_leader alexei navalny which bluntly blamed the moscow government once again the kremlin has used favorite weapon agent the novichok class chemicals effort silence political opponent the mark regime that paranoid that unwilling tolerate any criticism dissent but candidates can thing during campaign and something else once office sometimes they have little choice because circumstances the course events president joe_biden pursue muscular approach has suggested dont biden going fall head over heels butter putin david kramer who was assistant secretary state the administration george bush moscow has continued with disinformation campaign against him and dont hes going extend hand and lets nice added kramer fellow the mccain institute foreign_policy tank based washington mean reset don going try anything like kramer reference obama failed reset policy kramer thinks biden have focus largely domestic issues thanks the coronavirus pandemic and its economic impact and the extent able focus foreign_policy should not the high end the priority list told voa although added you cant ignore and factor number problems face hes going have devote his limited when comes foreign_policy work with countries that are ready solve problems that means shoring america transatlantic alliance biden and putin have met cordiality interview with magazine biden meeting told the leader looking into your eyes and don you have soul biden continued looked and smiled and understand another aside the lack personal rapport analysts any effort reset relations would complicated economic sanctions imposed both the obama and trump administrations the measures leave biden with little room maneuver and are unlikely lifted while western powers believe mounting cyberattacks against them former western diplomats antagonism likely persist between washington and moscow the kremlin seeks undermine western democratic institutions last_week former top security_adviser british prime_minister boris johnson mark sedwill revealed that britain has launched series covert cyber based attacks leaders and their interests impose price greater than they might have expected for their cyber offensive against the west other allied powers the are doing too western intelligence officials what becoming like for like cyber conflict with the kremlin the called gray space the gap between normal state relations and armed conflict the and other western powers are conflict with range issues the annexation crimea the pro moscow agitation east ukraine backing syria president bashar assad the attempted assassination salisbury england former double agent sergei skripal heather williams britain chatham house expects biden administration focus key areas restoring arms_control and strengthening nato check adventurism the hand the must maintain strong  ...

# %%
wordcloud = WordCloud(background_color='black', max_words=100)
wordcloud = wordcloud.generate(re_unit_text)
wordcloud.to_file('Top_50_news.png')
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F7DB492F7C0>
